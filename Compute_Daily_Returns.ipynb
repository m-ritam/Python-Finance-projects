# %%
import pandas as pd
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Defineing the file path
file_path = "/content/drive/My Drive/Excel file to use in colab/stock_prices.xlsx"

# %%
# Loading the Excel file
df = pd.read_excel(file_path)

# %%
# Computing daily returns
df["Daily Return"] = df["Stock Price"].pct_change() #pct_change -> Percentage change between the current and a prior element.

# %%
# Result display
df
# Out:
#          Date  Stock Price  Daily Return
# 0  2024-01-01          100           NaN
# 1  2024-01-02          102      0.020000
# 2  2024-01-03          101     -0.009804
# 3  2024-01-04          105      0.039604
# 4  2024-01-05          110      0.047619
