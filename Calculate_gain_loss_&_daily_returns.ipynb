# %%
import pandas as pd3
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/My Drive/Excel file to use in colab/3_mock_stock_data_with_time.xlsx"

# %%
df3 = pd3.read_excel(file_path)

# %%
df3["Daily Return (%)"] = df3["Close"].pct_change() * 100
df3["Gain/Loss"] = df["Close"].diff()

# %%
df3
# Out:
#          Date    Open    High     Low   Close   Volume  Daily Return (%)  \
# 0  2024-01-01  161.24  164.67  158.69  159.41  4433977               NaN
# 1  2024-01-02  178.52  180.20  176.43  179.12  1075766         12.364344
# 2  2024-01-03  171.96  173.22  167.65  171.89  3506075         -4.036400
# 3  2024-01-04  167.96  172.76  165.53  169.59  4560920         -1.338065
# 4  2024-01-05  154.68  159.54  152.56  157.94  3665702         -6.869509
# 5  2024-01-06  154.68  158.91  151.51  155.16  3484413         -1.760162
# 6  2024-01-07  151.74  153.96  150.18  152.16  3907360         -1.933488
# 7  2024-01-08  175.99  177.38  171.78  174.17  3782592         14.465037
# 8  2024-01-09  168.03  171.77  166.73  166.86  2701240         -4.197049
# 9  2024-01-10  171.24  174.00  166.29  167.12  1984346          0.155819
# 10 2024-01-11  150.62  152.11  146.53  146.71  2503165        -12.212781
# 11 2024-01-12  179.10  182.08  177.31  180.35  3235000         22.929589
# ...
